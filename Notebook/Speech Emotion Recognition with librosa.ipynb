# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd

import os
import sys

import librosa
import librosa.display
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

import IPython.display as ipd
from IPython.display import Audio

import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM,BatchNormalization , GRU
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD
# Out:
# 2024-03-26 13:17:21.770500: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-26 13:17:21.770558: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-26 13:17:21.772017: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Paths for data.

# %%
ravdess = "/kaggle/input/ravdess-emotional-speech-audio/audio_speech_actors_01-24/"
crema = "/kaggle/input/cremad/AudioWAV/"
tess = "/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/"
savee = "/kaggle/input/surrey-audiovisual-expressed-emotion-savee/ALL/"

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ##  <center> 1. Ravdess Dataframe <center>
# Here is the filename identifiers as per the official RAVDESS website:
#
# * Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
# * Vocal channel (01 = speech, 02 = song).
# * Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
# * Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
# * Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
# * Repetition (01 = 1st repetition, 02 = 2nd repetition).
# * Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# So, here's an example of an audio filename. 02-01-06-01-02-01-12.mp4
# This means the meta data for the audio file is:
#
# * Video-only (02)
# * Speech (01)
# * Fearful (06)
# * Normal intensity (01)
# * Statement "dogs" (02)
# * 1st Repetition (01)
# * 12th Actor (12) - Female (as the actor ID number is even)

# %%
os.listdir(ravdess)
# Out:
# ['Actor_02',
#  'Actor_17',
#  'Actor_05',
#  'Actor_16',
#  'Actor_21',
#  'Actor_01',
#  'Actor_11',
#  'Actor_20',
#  'Actor_08',
#  'Actor_15',
#  'Actor_06',
#  'Actor_12',
#  'Actor_23',
#  'Actor_24',
#  'Actor_22',
#  'Actor_04',
#  'Actor_19',
#  'Actor_10',
#  'Actor_09',
#  'Actor_14',
#  'Actor_03',
#  'Actor_13',
#  'Actor_18',
#  'Actor_07']

# %%
ravdess_dir = os.listdir(ravdess)

file_emotion = []
file_path = []

for dir in ravdess_dir:
    actor = os.listdir(ravdess + '/' + dir)
    for file in actor:
        part = file.split('.')[0]
        part = file.split('-')
        file_emotion.append(int(part[2]))
        file_path.append(ravdess + '/' + dir + '/' + file)

emotion_df = pd.DataFrame(file_emotion, columns = ['Emotions'])

path_df = pd.DataFrame( file_path, columns = ['Path'])

ravdees_df = pd.concat([emotion_df, path_df], axis=1)

ravdees_df.Emotions.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)

# %%
ravdees_df.head(5)
# Out:
#    Emotions                                               Path
# 0  surprise  /kaggle/input/ravdess-emotional-speech-audio/a...
# 1   neutral  /kaggle/input/ravdess-emotional-speech-audio/a...
# 2   disgust  /kaggle/input/ravdess-emotional-speech-audio/a...
# 3   disgust  /kaggle/input/ravdess-emotional-speech-audio/a...
# 4   neutral  /kaggle/input/ravdess-emotional-speech-audio/a...

# %%
print(ravdees_df['Path'].iloc[0])
# Out:
# /kaggle/input/ravdess-emotional-speech-audio/audio_speech_actors_01-24//Actor_02/03-01-08-01-01-01-02.wav

# %%
print(ravdees_df.Emotions.value_counts())
# Out:
# Emotions
# surprise    192
# disgust     192
# fear        192
# sad         192
# happy       192
# calm        192
# angry       192
# neutral      96
# Name: count, dtype: int64

# %% [markdown]
# ## <center>2. Crema DataFrame</center>

# %%
crema_dir = os.listdir(crema)

# %%
file_emotion = []
file_path = []

for file in crema_dir:
    file_path.append(crema + '/' + file)
    part = file.split('_')
    if part[2] == 'SAD':
        file_emotion.append('sad')
    elif part[2] == 'ANG':
        file_emotion.append('angry')
    elif part[2] == 'DIS':
        file_emotion.append('disgust')
    elif part[2] == 'FEA':
        file_emotion.append('fear')
    elif part[2] == 'HAP':
        file_emotion.append('happy')
    elif part[2] == 'NEU':
        file_emotion.append('neutral')
    else:
        file_emotion.append('Unknown')

emotion_df = pd.DataFrame(file_emotion, columns = ['Emotions'])

path_df = pd.DataFrame(file_path, columns = ['Path'])

crema_df = pd.concat([emotion_df, path_df], axis = 1)

# %%
crema_df.head(5)
# Out:
#   Emotions                                               Path
# 0  disgust  /kaggle/input/cremad/AudioWAV//1028_TSI_DIS_XX...
# 1    happy  /kaggle/input/cremad/AudioWAV//1075_IEO_HAP_LO...
# 2    happy  /kaggle/input/cremad/AudioWAV//1084_ITS_HAP_XX...
# 3  disgust  /kaggle/input/cremad/AudioWAV//1067_IWW_DIS_XX...
# 4  disgust  /kaggle/input/cremad/AudioWAV//1066_TIE_DIS_XX...

# %%
print(crema_df['Path'].iloc[0])
# Out:
# /kaggle/input/cremad/AudioWAV//1028_TSI_DIS_XX.wav

# %%
print(crema_df.Emotions.value_counts())
# Out:
# Emotions
# disgust    1271
# happy      1271
# sad        1271
# fear       1271
# angry      1271
# neutral    1087
# Name: count, dtype: int64

# %% [markdown]
# ## Tess dataset

# %%
os.listdir(tess)
# Out:
# ['YAF_fear',
#  'OAF_angry',
#  'OAF_Fear',
#  'OAF_disgust',
#  'OAF_neutral',
#  'YAF_angry',
#  'OAF_Sad',
#  'YAF_disgust',
#  'YAF_neutral',
#  'OAF_Pleasant_surprise',
#  'YAF_happy',
#  'OAF_happy',
#  'YAF_sad',
#  'YAF_pleasant_surprised']

# %%
tess_dir = os.listdir(tess)

file_emotion = []
file_path = []

for dir in tess_dir:
    directories = os.listdir(tess +'/'+ dir)
    for file in directories:
        part = file.split('.')[0]
        part = part.split('_')[2]
        if part=='ps':
            file_emotion.append('surprise')
        else:
            file_emotion.append(part)
        file_path.append(tess + '/' + dir + '/' + file)

# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
tess_df = pd.concat([emotion_df, path_df], axis=1)

# %%
tess_df.head(5)
# Out:
#   Emotions                                               Path
# 0     fear  /kaggle/input/toronto-emotional-speech-set-tes...
# 1     fear  /kaggle/input/toronto-emotional-speech-set-tes...
# 2     fear  /kaggle/input/toronto-emotional-speech-set-tes...
# 3     fear  /kaggle/input/toronto-emotional-speech-set-tes...
# 4     fear  /kaggle/input/toronto-emotional-speech-set-tes...

# %%
print(tess_df['Path'].iloc[0])
# Out:
# /kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data//YAF_fear/YAF_home_fear.wav

# %%
print(tess_df.Emotions.value_counts())
# Out:
# Emotions
# fear        400
# angry       400
# disgust     400
# neutral     400
# sad         400
# surprise    400
# happy       400
# Name: count, dtype: int64

# %% [markdown]
# ## SAVEE
#
# The audio files in this dataset are named in such a way that the prefix letters describes the emotion classes as follows:
#
# * 'a' = 'anger'
# * 'd' = 'disgust'
# * 'f' = 'fear'
# * 'h' = 'happiness'
# * 'n' = 'neutral'
# * 'sa' = 'sadness'
# * 'su' = 'surprise'

# %%
os.listdir(savee)
# Out:
# ['JE_h09.wav',
#  'KL_f12.wav',
#  'DC_h03.wav',
#  'DC_d04.wav',
#  'KL_a14.wav',
#  'JE_f01.wav',
#  'KL_h15.wav',
#  'JK_su02.wav',
#  'JK_a06.wav',
#  'DC_n01.wav',
#  'DC_f01.wav',
#  'JK_n22.wav',
#  'KL_a10.wav',
#  'JE_n08.wav',
#  'KL_sa13.wav',
#  'DC_a12.wav',
#  'JE_f07.wav',
#  'JE_d05.wav',
#  'KL_d09.wav',
#  'DC_n30.wav',
#  'KL_h05.wav',
#  'JE_f11.wav',
#  'JE_d08.wav',
#  'JE_d04.wav',
#  'KL_h09.wav',
#  'JE_f06.wav',
#  'DC_a15.wav',
#  'KL_a05.wav',
#  'KL_d01.wav',
#  'JK_sa06.wav',
#  'KL_n20.wav',
#  'JE_n17.wav',
#  'KL_n12.wav',
#  'DC_sa10.wav',
#  'JK_n01.wav',
#  'DC_h13.wav',
#  'KL_su05.wav',
#  'KL_n24.wav',
#  'JE_n05.wav',
#  'KL_sa06.wav',
#  'KL_f02.wav',
#  'JE_sa12.wav',
#  'DC_h05.wav',
#  'DC_f02.wav',
#  'JK_d12.wav',
#  'JE_d03.wav',
#  'JE_a06.wav',
#  'KL_su12.wav',
#  'JE_n23.wav',
#  'DC_sa15.wav',
#  'DC_f07.wav',
#  'DC_h15.wav',
#  'JK_su07.wav',
#  'DC_sa09.wav',
#  'KL_d12.wav',
#  'DC_sa06.wav',
#  'JE_sa03.wav',
#  'JE_sa13.wav',
#  'KL_su13.wav',
#  'KL_sa01.wav',
#  'DC_h06.wav',
#  'DC_su15.wav',
#  'DC_a03.wav',
#  'JK_d11.wav',
#  'KL_n27.wav',
#  'JE_a04.wav',
#  'JK_f08.wav',
#  'JE_sa02.wav',
#  'JK_n16.wav',
#  'DC_d06.wav',
#  'JK_su04.wav',
#  'JE_d15.wav',
#  'DC_n09.wav',
#  'DC_n17.wav',
#  'JE_su05.wav',
#  'JE_n14.wav',
#  'KL_h11.wav',
#  'DC_n16.wav',
#  'JK_n07.wav',
#  'JK_a15.wav',
#  'KL_sa07.wav',
#  'DC_a01.wav',
#  'JE_su11.wav',
#  'JE_su15.wav',
#  'KL_su07.wav',
#  'KL_d10.wav',
#  'JE_d10.wav',
#  'DC_su08.wav',
#  'JK_h03.wav',
#  'JK_a12.wav',
#  'DC_n08.wav',
#  'KL_n29.wav',
#  'KL_su15.wav',
#  'JE_h02.wav',
#  'DC_n11.wav',
#  'JE_a11.wav',
#  'KL_sa09.wav',
#  'KL_h13.wav',
#  'JK_h09.wav',
#  'JK_f03.wav',
#  'JE_n22.wav',
#  'JE_d07.wav',
#  'KL_su08.wav',
#  'DC_f04.wav',
#  'DC_n27.wav',
#  'KL_d02.wav',
#  'KL_su06.wav',
#  'KL_a12.wav',
#  'JE_su01.wav',
#  'JE_h07.wav',
#  'JE_n24.wav',
#  'KL_f08.wav',
#  'KL_h10.wav',
#  'DC_sa07.wav',
#  'JK_d09.wav',
#  'DC_a05.wav',
#  'JE_h14.wav',
#  'JE_n03.wav',
#  'DC_su07.wav',
#  'JK_h08.wav',
#  'KL_su01.wav',
#  'DC_su05.wav',
#  'JE_f12.wav',
#  'JE_d14.wav',
#  'JK_n17.wav',
#  'JE_su08.wav',
#  'JE_a02.wav',
#  'JE_n06.wav',
#  'KL_n10.wav',
#  'DC_h10.wav',
#  'KL_a11.wav',
#  'DC_n13.wav',
#  'JK_n13.wav',
#  'JK_su09.wav',
#  'JE_f08.wav',
#  'DC_n29.wav',
#  'JK_n24.wav',
#  'KL_f03.wav',
#  'JK_n09.wav',
#  'KL_n13.wav',
#  'JE_f02.wav',
#  'KL_su02.wav',
#  'KL_n09.wav',
#  'DC_su14.wav',
#  'JK_h12.wav',
#  'KL_sa08.wav',
#  'JE_sa15.wav',
#  'JE_n04.wav',
#  'DC_f14.wav',
#  'DC_n05.wav',
#  'JE_sa05.wav',
#  'JE_d09.wav',
#  'KL_f13.wav',
#  'KL_d05.wav',
#  'JE_h01.wav',
#  'DC_a07.wav',
#  'KL_d15.wav',
#  'JK_sa07.wav',
#  'JK_su15.wav',
#  'DC_sa03.wav',
#  'DC_a02.wav',
#  'KL_a08.wav',
#  'JK_f04.wav',
#  'DC_f03.wav',
#  'KL_f01.wav',
#  'JK_n26.wav',
#  'JK_sa01.wav',
#  'JE_n30.wav',
#  'KL_n16.wav',
#  'JK_h04.wav',
#  'KL_sa02.wav',
#  'DC_n24.wav',
#  'JE_h12.wav',
#  'JE_f03.wav',
#  'DC_n14.wav',
#  'JK_h14.wav',
#  'JK_n29.wav',
#  'DC_n10.wav',
#  'KL_su09.wav',
#  'KL_sa12.wav',
#  'JE_f15.wav',
#  'JK_sa03.wav',
#  'KL_a13.wav',
#  'JK_h02.wav',
#  'DC_sa05.wav',
#  'JK_n05.wav',
#  'JE_a13.wav',
#  'JE_h05.wav',
#  'JK_f07.wav',
#  'JE_sa04.wav',
#  'DC_h07.wav',
#  'JE_d02.wav',
#  'JK_d04.wav',
#  'KL_a03.wav',
#  'DC_a13.wav',
#  'KL_n04.wav',
#  'JE_su12.wav',
#  'JK_n03.wav',
#  'JK_n25.wav',
#  'DC_f06.wav',
#  'JE_f04.wav',
#  'JE_h06.wav',
#  'DC_h02.wav',
#  'JK_su08.wav',
#  'JE_n01.wav',
#  'DC_h08.wav',
#  'KL_su04.wav',
#  'DC_d10.wav',
#  'JK_n27.wav',
#  'JK_a08.wav',
#  'JK_n30.wav',
#  'DC_f15.wav',
#  'JE_d11.wav',
#  'JK_h10.wav',
#  'JE_n20.wav',
#  'JK_d14.wav',
#  'KL_h02.wav',
#  'JE_f05.wav',
#  'DC_d12.wav',
#  'JK_sa13.wav',
#  'JK_f01.wav',
#  'JE_h15.wav',
#  'JE_su02.wav',
#  'JK_a02.wav',
#  'KL_f09.wav',
#  'KL_sa10.wav',
#  'DC_d01.wav',
#  'JE_n26.wav',
#  'KL_su03.wav',
#  'DC_a10.wav',
#  'JK_a09.wav',
#  'JK_h11.wav',
#  'JE_h11.wav',
#  'DC_n23.wav',
#  'KL_n22.wav',
#  'JK_d01.wav',
#  'DC_f08.wav',
#  'DC_h14.wav',
#  'JK_su03.wav',
#  'JE_h10.wav',
#  'DC_n18.wav',
#  'KL_n23.wav',
#  'JE_su13.wav',
#  'DC_n20.wav',
#  'DC_d11.wav',
#  'DC_d13.wav',
#  'DC_a11.wav',
#  'KL_a06.wav',
#  'JE_n16.wav',
#  'KL_d04.wav',
#  'DC_su13.wav',
#  'JK_sa08.wav',
#  'KL_n08.wav',
#  'KL_n18.wav',
#  'DC_h01.wav',
#  'DC_f11.wav',
#  'JK_d07.wav',
#  'JK_su12.wav',
#  'DC_a06.wav',
#  'JE_sa11.wav',
#  'JE_n12.wav',
#  'DC_n03.wav',
#  'KL_n14.wav',
#  'JE_sa01.wav',
#  'JE_h13.wav',
#  'KL_su14.wav',
#  'JK_d03.wav',
#  'JE_su10.wav',
#  'DC_n19.wav',
#  'DC_su03.wav',
#  'JK_su13.wav',
#  'KL_a04.wav',
#  'JE_a03.wav',
#  'KL_f11.wav',
#  'DC_d02.wav',
#  'KL_a07.wav',
#  'JK_n19.wav',
#  'JE_f09.wav',
#  'JE_su06.wav',
#  'DC_su01.wav',
#  'DC_h11.wav',
#  'JK_sa02.wav',
#  'KL_n19.wav',
#  'JK_su10.wav',
#  'JK_n20.wav',
#  'KL_d07.wav',
#  'DC_n28.wav',
#  'JK_f13.wav',
#  'DC_f05.wav',
#  'DC_f10.wav',
#  'KL_h04.wav',
#  'JK_f14.wav',
#  'KL_f15.wav',
#  'JK_su06.wav',
#  'JK_n04.wav',
#  'JK_a07.wav',
#  'JK_d10.wav',
#  'JE_h04.wav',
#  'JK_d15.wav',
#  'JK_f12.wav',
#  'JE_sa07.wav',
#  'JE_n27.wav',
#  'KL_d06.wav',
#  'JK_a03.wav',
#  'KL_n01.wav',
#  'DC_su06.wav',
#  'JK_f02.wav',
#  'JK_f10.wav',
#  'JE_su04.wav',
#  'DC_n21.wav',
#  'JE_h08.wav',
#  'JE_f14.wav',
#  'JK_n21.wav',
#  'KL_su11.wav',
#  'JK_sa15.wav',
#  'JE_d13.wav',
#  'KL_a01.wav',
#  'JK_h05.wav',
#  'JE_f10.wav',
#  'JK_d08.wav',
#  'JK_a10.wav',
#  'KL_f04.wav',
#  'KL_n26.wav',
#  'KL_d08.wav',
#  'JK_d06.wav',
#  'KL_sa11.wav',
#  'DC_sa04.wav',
#  'JE_n28.wav',
#  'KL_n05.wav',
#  'JK_h15.wav',
#  'DC_d03.wav',
#  'JK_sa14.wav',
#  'JE_h03.wav',
#  'DC_su11.wav',
#  'DC_d07.wav',
#  'KL_sa14.wav',
#  'KL_n11.wav',
#  'JE_n07.wav',
#  'JK_sa05.wav',
#  'KL_n25.wav',
#  'JE_d01.wav',
#  'JK_n11.wav',
#  'KL_f14.wav',
#  'JK_n14.wav',
#  'JK_n12.wav',
#  'JE_sa10.wav',
#  'JE_a05.wav',
#  'KL_f06.wav',
#  'JK_h06.wav',
#  'DC_d14.wav',
#  'KL_n17.wav',
#  'DC_a04.wav',
#  'JK_n08.wav',
#  'KL_n02.wav',
#  'JK_f09.wav',
#  'DC_f09.wav',
#  'DC_h12.wav',
#  'KL_n06.wav',
#  'DC_n12.wav',
#  'JE_a09.wav',
#  'JE_a14.wav',
#  'JE_n13.wav',
#  'KL_h08.wav',
#  'JE_sa06.wav',
#  'KL_n15.wav',
#  'JK_h13.wav',
#  'KL_n30.wav',
#  'DC_sa08.wav',
#  'KL_h07.wav',
#  'JE_a07.wav',
#  'JE_d12.wav',
#  'KL_d13.wav',
#  'DC_d09.wav',
#  'KL_a15.wav',
#  'JK_f11.wav',
#  'JE_su03.wav',
#  'DC_n07.wav',
#  'DC_f13.wav',
#  'JE_su14.wav',
#  'KL_h01.wav',
#  'JE_f13.wav',
#  'KL_n07.wav',
#  'JE_a15.wav',
#  'DC_f12.wav',
#  'KL_f05.wav',
#  'JK_a05.wav',
#  'JK_sa09.wav',
#  'DC_d15.wav',
#  'DC_h09.wav',
#  'KL_f07.wav',
#  'DC_d05.wav',
#  'JE_a10.wav',
#  'DC_n04.wav',
#  'KL_n21.wav',
#  'JK_f05.wav',
#  'JE_a01.wav',
#  'KL_h03.wav',
#  'JK_n15.wav',
#  'DC_sa13.wav',
#  'DC_h04.wav',
#  'DC_n25.wav',
#  'DC_su09.wav',
#  'JE_a12.wav',
#  'DC_sa12.wav',
#  'JE_n11.wav',
#  'JE_n15.wav',
#  'DC_su12.wav',
#  'JE_sa09.wav',
#  'DC_n22.wav',
#  'JK_f06.wav',
#  'JE_su07.wav',
#  'JK_n10.wav',
#  'JK_a14.wav',
#  'JK_d05.wav',
#  'JE_n21.wav',
#  'DC_n06.wav',
#  'DC_n02.wav',
#  'JK_a04.wav',
#  'JK_n28.wav',
#  'DC_sa11.wav',
#  'JK_a01.wav',
#  'JK_sa10.wav',
#  'JK_su11.wav',
#  'KL_h06.wav',
#  'JK_h01.wav',
#  'KL_sa03.wav',
#  'KL_a02.wav',
#  'JK_d13.wav',
#  'DC_su04.wav',
#  'JK_n02.wav',
#  'JE_n18.wav',
#  'JK_d02.wav',
#  'JE_d06.wav',
#  'KL_sa05.wav',
#  'DC_sa02.wav',
#  'DC_a14.wav',
#  'KL_d11.wav',
#  'JE_n10.wav',
#  'DC_a08.wav',
#  'JE_su09.wav',
#  'KL_d03.wav',
#  'JE_sa08.wav',
#  'KL_su10.wav',
#  'DC_n15.wav',
#  'KL_h12.wav',
#  'JE_sa14.wav',
#  'JK_sa12.wav',
#  'JK_f15.wav',
#  'JK_n06.wav',
#  'DC_d08.wav',
#  'JE_a08.wav',
#  'KL_n03.wav',
#  'JK_a13.wav',
#  'DC_sa01.wav',
#  'KL_n28.wav',
#  'KL_d14.wav',
#  'KL_f10.wav',
#  'JE_n19.wav',
#  'JK_sa11.wav',
#  'JE_n25.wav',
#  'JK_su01.wav',
#  'JE_n29.wav',
#  'DC_sa14.wav',
#  'JK_su05.wav',
#  'KL_sa15.wav',
#  'KL_sa04.wav',
#  'JK_a11.wav',
#  'JE_n09.wav',
#  'DC_su10.wav',
#  'JK_h07.wav',
#  'DC_a09.wav',
#  'JK_n23.wav',
#  'DC_su02.wav',
#  'JK_n18.wav',
#  'JK_sa04.wav',
#  'JK_su14.wav',
#  'DC_n26.wav',
#  'JE_n02.wav',
#  'KL_a09.wav',
#  'KL_h14.wav']

# %%
savee_dir = os.listdir(savee)

file_emotion = []
file_path = []

for file in savee_dir:
    file_path.append(savee + '/' + file)
    part = file.split('_')[1]
    ele = part[:-6]
    if ele=='a':
        file_emotion.append('angry')
    elif ele=='d':
        file_emotion.append('disgust')
    elif ele=='f':
        file_emotion.append('fear')
    elif ele=='h':
        file_emotion.append('happy')
    elif ele=='n':
        file_emotion.append('neutral')
    elif ele=='sa':
        file_emotion.append('sad')
    else:
        file_emotion.append('surprise')

# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
savee_df = pd.concat([emotion_df, path_df], axis=1)

# %%
savee_df
# Out:
#      Emotions                                               Path
# 0       happy  /kaggle/input/surrey-audiovisual-expressed-emo...
# 1        fear  /kaggle/input/surrey-audiovisual-expressed-emo...
# 2       happy  /kaggle/input/surrey-audiovisual-expressed-emo...
# 3     disgust  /kaggle/input/surrey-audiovisual-expressed-emo...
# 4       angry  /kaggle/input/surrey-audiovisual-expressed-emo...
# ..        ...                                                ...
# 475  surprise  /kaggle/input/surrey-audiovisual-expressed-emo...
# 476   neutral  /kaggle/input/surrey-audiovisual-expressed-emo...
# 477   neutral  /kaggle/input/surrey-audiovisual-expressed-emo...
# 478     angry  /kaggle/input/surrey-audiovisual-expressed-emo...
# 479     happy  /kaggle/input/surrey-audiovisual-expressed-emo...
#
# [480 rows x 2 columns]

# %%
print(savee_df['Path'].iloc[0])
# Out:
# /kaggle/input/surrey-audiovisual-expressed-emotion-savee/ALL//JE_h09.wav

# %%
print(savee_df.Emotions.value_counts())
# Out:
# Emotions
# neutral     120
# fear         60
# happy        60
# disgust      60
# angry        60
# surprise     60
# sad          60
# Name: count, dtype: int64

# %% [markdown]
# ## Dataframe using all the 4 dataframes

# %%
data_path = pd.concat([ravdees_df, crema_df, tess_df, savee_df], axis = 0)

# %%
data_path.to_csv("data_path.csv", index = False )

# %%
data_path.head(5)
# Out:
#    Emotions                                               Path
# 0  surprise  /kaggle/input/ravdess-emotional-speech-audio/a...
# 1   neutral  /kaggle/input/ravdess-emotional-speech-audio/a...
# 2   disgust  /kaggle/input/ravdess-emotional-speech-audio/a...
# 3   disgust  /kaggle/input/ravdess-emotional-speech-audio/a...
# 4   neutral  /kaggle/input/ravdess-emotional-speech-audio/a...

# %%
print(data_path.Emotions.value_counts())
# Out:
# Emotions
# fear        1923
# disgust     1923
# happy       1923
# sad         1923
# angry       1923
# neutral     1703
# surprise     652
# calm         192
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.title('Count of Emotions', size=16)
sns.countplot(x='Emotions', data=data_path)
plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
plt.show()

# %%
data_path.shape
# Out:
# (12162, 2)

# %%
data,sr = librosa.load(file_path[0])
sr
# Out:
# 22050

# %% [markdown]
# ## Data Argumentation

# %%
# NOISE
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

# STRETCH
def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate = rate)
# SHIFT
def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)
# PITCH
def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=pitch_factor)

# %% [markdown]
# # Normal Audio

# %%
plt.figure(figsize= (12,5))
librosa.display.waveshow(y = data , sr = sr)
ipd.Audio(data, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Audio with Noise

# %%
x= noise(data)
plt.figure(figsize = (12,5))
librosa.display.waveshow(y = data , sr = sr)
ipd.Audio(x, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Streched Audio

# %%
x = stretch(data, rate=0.8)
plt.figure(figsize=(12, 5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #Shifted audio

# %%
x = shift(data)
plt.figure(figsize = (12,5))
librosa.display.waveshow(y = data , sr = sr)
ipd.Audio(x, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #Audio with pitch

# %%
x = pitch(data, sr, pitch_factor=0.7)
plt.figure(figsize=(12, 5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Feature Extraction

# %%
def zcr(data,frame_length,hop_length):
    zcr=librosa.feature.zero_crossing_rate(data,frame_length=frame_length,hop_length=hop_length)
    return np.squeeze(zcr)

def rmse(data, frame_length=2048, hop_length=512):
    rmse = librosa.feature.rms(y=data, frame_length=frame_length, hop_length=hop_length)
    return np.squeeze(rmse)

def mfcc(data, sr, frame_lenght = 2048, hop_length = 512, flatten:bool = True):
  mfcc = librosa.feature.mfcc(y = data,sr = sr)
  return np.squeeze(mfcc.T) if not flatten else np.ravel(mfcc.T)

# %%
def extract_feature(data, sr = 22050, frame_length = 2048, hop_length = 512):
  result = np.array([])
  zcr_result = zcr(data, frame_length, hop_length)
  rmse_result = rmse(data, frame_length, hop_length)
  mfcc_result = mfcc(data, sr, frame_length, hop_length)

  result = np.hstack([zcr_result, rmse_result, mfcc_result])
  return result

# %%
def get_features(path, duration = 2.5, offset = 0.6):
  data, sr = librosa.load(path, duration = duration, offset = offset)
  aud = extract_feature(data)
  audio = np.array(aud)

  noised_audio = noise(data)
  aud2 = extract_feature(noised_audio)
  audio = np.vstack((audio,aud2))

  pitched_audio = pitch(data, sr)
  aud3 = extract_feature(pitched_audio)
  audio = np.vstack((audio, aud3))

  pitched_noised_audio = noise(pitched_audio)
  aud4 = extract_feature(pitched_noised_audio)
  audio = np.vstack((audio, aud4))

  return audio

# %%
import multiprocessing as mp
print("Number of processors: ", mp.cpu_count())
# Out:
# Number of processors:  4

# %% [markdown]
# ## Get Feature

# %%
import timeit
from tqdm import tqdm
start = timeit.default_timer()
X,Y=[],[]
for path,emotion,index in tqdm (zip(data_path.Path,data_path.Emotions,range(data_path.Path.shape[0]))):
    features=get_features(path)
    if index%500==0:
        print(f'{index} audio has been processed')
    for i in features:
        X.append(i)
        Y.append(emotion)
print('Done')
stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# 1it [00:00,  4.28it/s]
# 0 audio has been processed
# 501it [01:57,  4.45it/s]
# 500 audio has been processed
# 1001it [03:49,  4.44it/s]
# 1000 audio has been processed
# 1502it [05:42,  5.56it/s]
# 1500 audio has been processed
# 2002it [07:14,  6.27it/s]
# 2000 audio has been processed
# 2502it [08:44,  5.50it/s]
# 2500 audio has been processed
# 3002it [10:13,  5.66it/s]
# 3000 audio has been processed
# 3502it [11:42,  5.89it/s]
# 3500 audio has been processed
# 4002it [13:13,  5.72it/s]
# 4000 audio has been processed
# 4502it [14:43,  6.20it/s]
# 4500 audio has been processed
# 5002it [16:15,  5.78it/s]
# 5000 audio has been processed
# 5502it [17:43,  6.08it/s]
# 5500 audio has been processed
# 6001it [19:16,  4.83it/s]
# 6000 audio has been processed
# 6501it [20:47,  5.10it/s]
# 6500 audio has been processed
# 7002it [22:17,  5.17it/s]
# 7000 audio has been processed
# 7502it [23:47,  5.84it/s]
# 7500 audio has been processed
# 8001it [25:17,  6.06it/s]
# 8000 audio has been processed
# 8501it [26:47,  5.11it/s]
# 8500 audio has been processed
# 9002it [28:11,  8.52it/s]
# 9000 audio has been processed
# 9502it [29:11,  6.64it/s]
# 9500 audio has been processed
# 10002it [30:30,  6.55it/s]
# 10000 audio has been processed
# 10502it [31:58,  7.09it/s]
# 10500 audio has been processed
# 11002it [33:11,  6.63it/s]
# 11000 audio has been processed
# 11502it [34:28,  7.56it/s]
# 11500 audio has been processed
# 12001it [35:45,  5.61it/s]
# 12000 audio has been processed
# 12162it [36:15,  5.59it/s]
# Done
# Time:  2175.348426888

# %%
len(X), len(Y), data_path.Path.shape
# Out:
# (48648, 48648, (12162,))

# %% [markdown]
# ## Saving Feature

# %%
Emotions = pd.DataFrame(X)
Emotions['Emotions'] = Y
Emotions.to_csv('emotion.csv', index=False)
Emotions.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.343750  0.479492  0.573730  0.458008  0.375488  0.301758  0.269043
# 1  0.243652  0.379395  0.478516  0.428711  0.376953  0.304688  0.267090
# 2  0.304199  0.427246  0.540039  0.471191  0.387207  0.333008  0.282227
# 3  0.252441  0.382324  0.507324  0.500000  0.494141  0.488281  0.485352
# 4  0.437500  0.659668  0.862305  0.878906  0.865234  0.847168  0.845703
#
#           7         8         9  ...      2367      2368      2369      2370  \
# 0  0.255371  0.251465  0.251953  ... -1.517690 -1.716483 -1.599310 -1.234609
# 1  0.255371  0.254395  0.252930  ... -1.105768 -1.284379 -1.257547 -1.079299
# 2  0.259277  0.258789  0.252930  ...  0.518303  0.838663  1.308733  1.855111
# 3  0.485352  0.498047  0.511719  ...  4.790740  1.077941 -2.316622 -3.321612
# 4  0.827637  0.835938  0.667969  ...  2.586417  2.746852  2.223276  0.986916
#
#        2371      2372      2373      2374      2375  Emotions
# 0 -0.693198 -0.038982  0.675206  1.405603  2.112303  surprise
# 1 -0.778914 -0.364632  0.164706  0.804545  1.531273  surprise
# 2  2.405192  2.896439  3.283493  3.541682  3.667480  surprise
# 3  2.437364  0.888346  3.061873 -1.511936 -3.109942  surprise
# 4 -0.730695 -2.530884 -4.002834 -4.849372 -4.929744   neutral
#
# [5 rows x 2377 columns]

# %%
Emotions = Emotions.fillna(0)

# %%
import numpy as np
import pandas as pd

import os
import sys

import librosa
import librosa.display
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

import IPython.display as ipd
from IPython.display import Audio

import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM,BatchNormalization , GRU
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD

# %%
Emotions = pd.read_csv('/kaggle/input/emotions/emotion.csv')
Emotions.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.090332  0.136719  0.152344  0.154297  0.120117  0.134766  0.165527
# 1  0.252441  0.371094  0.483887  0.481445  0.480469  0.486328  0.508301
# 2  0.063965  0.090820  0.101074  0.114746  0.104492  0.154297  0.210449
# 3  0.237305  0.359863  0.487305  0.487305  0.486328  0.478027  0.472168
# 4  0.065918  0.099609  0.159668  0.166504  0.192871  0.197266  0.176758
#
#           7         8         9  ...      2367       2368      2369      2370  \
# 0  0.193848  0.208496  0.162109  ...  4.043136   5.765306  6.346148  5.203500
# 1  0.513184  0.511719  0.512695  ... -2.986572  -2.788266  0.661218 -1.169518
# 2  0.244629  0.226562  0.177246  ...  2.500613   4.326787  4.353564  2.234883
# 3  0.476074  0.484375  0.505371  ... -0.511819  -0.638016 -0.997156 -1.401101
# 4  0.169922  0.160645  0.183105  ... -2.686041  12.111397  7.391188  2.090285
#
#         2371       2372      2373       2374       2375  Emotions
# 0   4.668551   4.742602  2.093227  -4.006017  -9.263257      calm
# 1  -0.952499  -1.781004 -7.027017  -3.942681  -0.463803      calm
# 2   0.389981   0.115879 -0.630774  -3.899069  -8.108342      calm
# 3   2.070604   0.786888 -3.810704  -2.698174   3.201873      calm
# 4  16.099852  18.863033  2.468784  13.105180  10.581881     happy
#
# [5 rows x 2377 columns]

# %%
print(Emotions.isna().any())
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 2372         True
# 2373         True
# 2374         True
# 2375         True
# Emotions    False
# Length: 2377, dtype: bool

# %%
Emotions=Emotions.fillna(0)
print(Emotions.isna().any())
Emotions.shape
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 2372        False
# 2373        False
# 2374        False
# 2375        False
# Emotions    False
# Length: 2377, dtype: bool
# (48728, 2377)

# %% [markdown]
# ## Data Preparation

# %%
X = Emotions.iloc[: ,:-1].values
Y = Emotions['Emotions'].values

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
X.shape
# Out:
# (48728, 2376)

# %%
Y.shape
# Out:
# (48728, 8)

# %%
##Data preparation

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=42,test_size=0.2, shuffle=True)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((38982, 2376), (38982, 8), (9746, 2376), (9746, 8))

# %%
#reshape for lstm
X_train = x_train.reshape(x_train.shape[0] , x_train.shape[1] , 1)
X_test = x_test.reshape(x_test.shape[0] , x_test.shape[1] , 1)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((38982, 2376), (38982, 8), (9746, 2376), (9746, 8))

# %%
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM,BatchNormalization , GRU
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# ##Applying early stopping for all models

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

model_checkpoint = ModelCheckpoint('/kaggle/working/best_model1_weights.keras', monitor='val_accuracy', save_best_only=True)
early_stop = EarlyStopping(monitor='val_accuracy', mode='max', patience=5, restore_best_weights=True)
lr_reduction=ReduceLROnPlateau(monitor='val_accuracy',patience=3,verbose=1,factor=0.5,min_lr=0.00001)

# %% [markdown]
# ## CNN Model

# %%
#Reshape for CNN_LSTM MODEL

x_traincnn =np.expand_dims(x_train, axis=2)
x_testcnn= np.expand_dims(x_test, axis=2)

# %%
print("Shape of x_testcnn:", x_traincnn.shape)
# Out:
# Shape of x_testcnn: (38982, 2376, 1)

# %%
print("Shape of x_testcnn:", x_testcnn.shape)
# Out:
# Shape of x_testcnn: (9746, 2376, 1)

# %%
import tensorflow.keras.layers as L
import tensorflow as tf

input_shape = (X_train.shape[1],1)
model = tf.keras.Sequential([
    L.Conv1D(512,kernel_size=5, strides=1,padding='same', activation='relu',input_shape=input_shape),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),

    L.Conv1D(512,kernel_size=5,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),
    Dropout(0.2),  # Add dropout layer after the second max pooling layer

    L.Conv1D(256,kernel_size=5,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),

    L.Conv1D(256,kernel_size=3,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=5,strides=2,padding='same'),
    Dropout(0.2),  # Add dropout layer after the fourth max pooling layer

    L.Conv1D(128,kernel_size=3,strides=1,padding='same',activation='relu'),
    L.BatchNormalization(),
    L.MaxPool1D(pool_size=3,strides=2,padding='same'),
    Dropout(0.2),  # Add dropout layer after the fifth max pooling layer

    L.Flatten(),
    L.Dense(512,activation='relu'),
    L.BatchNormalization(),
    L.Dense(8,activation='softmax')
])
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_5 (Conv1D)               │ (None, 2376, 512)      │         3,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 2376, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_5 (MaxPooling1D)  │ (None, 1188, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 1188, 512)      │     1,311,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 1188, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 594, 512)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 594, 512)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 594, 256)       │       655,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 594, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 297, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 297, 256)       │       196,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 297, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_8 (MaxPooling1D)  │ (None, 149, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 149, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 149, 128)       │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 149, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_9 (MaxPooling1D)  │ (None, 75, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 75, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 9600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │     4,915,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8)              │         4,104 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,193,736 (27.44 MB)
#  Trainable params: 7,189,384 (27.43 MB)
#  Non-trainable params: 4,352 (17.00 KB)

# %%
history = model.fit(x_traincnn, y_train, epochs=50, validation_data=(x_testcnn, y_test), batch_size=64,callbacks=[early_stop,lr_reduction,model_checkpoint])
# Out:
# Epoch 1/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.5235 - loss: 1.2366 - val_accuracy: 0.5731 - val_loss: 1.1081 - learning_rate: 0.0010
# Epoch 2/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 135ms/step - accuracy: 0.6003 - loss: 1.0359 - val_accuracy: 0.5709 - val_loss: 1.1425 - learning_rate: 0.0010
# Epoch 3/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 135ms/step - accuracy: 0.6599 - loss: 0.8855 - val_accuracy: 0.6692 - val_loss: 0.8591 - learning_rate: 0.0010
# Epoch 4/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.7079 - loss: 0.7684 - val_accuracy: 0.7032 - val_loss: 0.7869 - learning_rate: 0.0010
# Epoch 5/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.7678 - loss: 0.6220 - val_accuracy: 0.7399 - val_loss: 0.6943 - learning_rate: 0.0010
# Epoch 6/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 84s 137ms/step - accuracy: 0.8287 - loss: 0.4750 - val_accuracy: 0.7838 - val_loss: 0.6239 - learning_rate: 0.0010
# Epoch 7/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 141s 136ms/step - accuracy: 0.8745 - loss: 0.3575 - val_accuracy: 0.8208 - val_loss: 0.4972 - learning_rate: 0.0010
# Epoch 8/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 84s 137ms/step - accuracy: 0.9062 - loss: 0.2761 - val_accuracy: 0.8861 - val_loss: 0.3388 - learning_rate: 0.0010
# Epoch 9/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9180 - loss: 0.2341 - val_accuracy: 0.8764 - val_loss: 0.3686 - learning_rate: 0.0010
# Epoch 10/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 137ms/step - accuracy: 0.9356 - loss: 0.1933 - val_accuracy: 0.8846 - val_loss: 0.3517 - learning_rate: 0.0010
# Epoch 11/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 84s 137ms/step - accuracy: 0.9027 - loss: 0.2717 - val_accuracy: 0.9332 - val_loss: 0.2105 - learning_rate: 0.0010
# Epoch 12/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9717 - loss: 0.0922 - val_accuracy: 0.9379 - val_loss: 0.1956 - learning_rate: 0.0010
# Epoch 13/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9570 - loss: 0.1291 - val_accuracy: 0.9209 - val_loss: 0.2483 - learning_rate: 0.0010
# Epoch 14/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9620 - loss: 0.1119 - val_accuracy: 0.9107 - val_loss: 0.2918 - learning_rate: 0.0010
# Epoch 15/50
# 609/610 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9696 - loss: 0.0928
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9696 - loss: 0.0927 - val_accuracy: 0.9333 - val_loss: 0.2095 - learning_rate: 0.0010
# Epoch 16/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 137ms/step - accuracy: 0.9813 - loss: 0.0563 - val_accuracy: 0.9669 - val_loss: 0.1133 - learning_rate: 5.0000e-04
# Epoch 17/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 137ms/step - accuracy: 0.9928 - loss: 0.0265 - val_accuracy: 0.9685 - val_loss: 0.1075 - learning_rate: 5.0000e-04
# Epoch 18/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9941 - loss: 0.0225 - val_accuracy: 0.9673 - val_loss: 0.1117 - learning_rate: 5.0000e-04
# Epoch 19/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 137ms/step - accuracy: 0.9884 - loss: 0.0402 - val_accuracy: 0.9666 - val_loss: 0.1141 - learning_rate: 5.0000e-04
# Epoch 20/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 84s 137ms/step - accuracy: 0.9906 - loss: 0.0314 - val_accuracy: 0.9700 - val_loss: 0.1079 - learning_rate: 5.0000e-04
# Epoch 21/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 137ms/step - accuracy: 0.9945 - loss: 0.0195 - val_accuracy: 0.9726 - val_loss: 0.0955 - learning_rate: 5.0000e-04
# Epoch 22/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9955 - loss: 0.0159 - val_accuracy: 0.9669 - val_loss: 0.1108 - learning_rate: 5.0000e-04
# Epoch 23/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9893 - loss: 0.0342 - val_accuracy: 0.9627 - val_loss: 0.1384 - learning_rate: 5.0000e-04
# Epoch 24/50
# 609/610 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9905 - loss: 0.0277
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9905 - loss: 0.0277 - val_accuracy: 0.9674 - val_loss: 0.1179 - learning_rate: 5.0000e-04
# Epoch 25/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 137ms/step - accuracy: 0.9963 - loss: 0.0140 - val_accuracy: 0.9764 - val_loss: 0.0860 - learning_rate: 2.5000e-04
# Epoch 26/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9967 - loss: 0.0108 - val_accuracy: 0.9743 - val_loss: 0.0876 - learning_rate: 2.5000e-04
# Epoch 27/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9965 - loss: 0.0124 - val_accuracy: 0.9753 - val_loss: 0.0914 - learning_rate: 2.5000e-04
# Epoch 28/50
# 609/610 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9916 - loss: 0.0276
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9916 - loss: 0.0276 - val_accuracy: 0.9761 - val_loss: 0.0881 - learning_rate: 2.5000e-04
# Epoch 29/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 84s 137ms/step - accuracy: 0.9978 - loss: 0.0075 - val_accuracy: 0.9781 - val_loss: 0.0807 - learning_rate: 1.2500e-04
# Epoch 30/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9983 - loss: 0.0069 - val_accuracy: 0.9767 - val_loss: 0.0849 - learning_rate: 1.2500e-04
# Epoch 31/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9987 - loss: 0.0058 - val_accuracy: 0.9780 - val_loss: 0.0813 - learning_rate: 1.2500e-04
# Epoch 32/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9987 - loss: 0.0056 - val_accuracy: 0.9793 - val_loss: 0.0797 - learning_rate: 1.2500e-04
# Epoch 33/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9990 - loss: 0.0043 - val_accuracy: 0.9804 - val_loss: 0.0781 - learning_rate: 1.2500e-04
# Epoch 34/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9991 - loss: 0.0043 - val_accuracy: 0.9809 - val_loss: 0.0790 - learning_rate: 1.2500e-04
# Epoch 35/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 135ms/step - accuracy: 0.9992 - loss: 0.0041 - val_accuracy: 0.9809 - val_loss: 0.0795 - learning_rate: 1.2500e-04
# Epoch 36/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9993 - loss: 0.0034 - val_accuracy: 0.9803 - val_loss: 0.0832 - learning_rate: 1.2500e-04
# Epoch 37/50
# 609/610 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9992 - loss: 0.0041
# Epoch 37: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9992 - loss: 0.0041 - val_accuracy: 0.9802 - val_loss: 0.0810 - learning_rate: 1.2500e-04
# Epoch 38/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 135ms/step - accuracy: 0.9994 - loss: 0.0032 - val_accuracy: 0.9807 - val_loss: 0.0766 - learning_rate: 6.2500e-05
# Epoch 39/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9994 - loss: 0.0026 - val_accuracy: 0.9814 - val_loss: 0.0765 - learning_rate: 6.2500e-05
# Epoch 40/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9989 - loss: 0.0037 - val_accuracy: 0.9816 - val_loss: 0.0772 - learning_rate: 6.2500e-05
# Epoch 41/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9989 - loss: 0.0044 - val_accuracy: 0.9817 - val_loss: 0.0761 - learning_rate: 6.2500e-05
# Epoch 42/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9995 - loss: 0.0026 - val_accuracy: 0.9819 - val_loss: 0.0762 - learning_rate: 6.2500e-05
# Epoch 43/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9991 - loss: 0.0033 - val_accuracy: 0.9829 - val_loss: 0.0746 - learning_rate: 6.2500e-05
# Epoch 44/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 135ms/step - accuracy: 0.9995 - loss: 0.0025 - val_accuracy: 0.9817 - val_loss: 0.0757 - learning_rate: 6.2500e-05
# Epoch 45/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9994 - loss: 0.0026 - val_accuracy: 0.9824 - val_loss: 0.0741 - learning_rate: 6.2500e-05
# Epoch 46/50
# 609/610 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9994 - loss: 0.0024
# Epoch 46: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 136ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 0.9819 - val_loss: 0.0745 - learning_rate: 6.2500e-05
# Epoch 47/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 83s 135ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 0.9818 - val_loss: 0.0750 - learning_rate: 3.1250e-05
# Epoch 48/50
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 142s 136ms/step - accuracy: 0.9996 - loss: 0.0021 - val_accuracy: 0.9828 - val_loss: 0.0741 - learning_rate: 3.1250e-05

# %%
model.save("speech_emotion_recognition.h5")

# %%
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']


print("Training Accuracy:", train_acc[-1])
print("Validation Accuracy:", val_acc[-1])
# Out:
# Training Accuracy: 0.999538242816925
# Validation Accuracy: 0.9827621579170227

# %%
import matplotlib.pyplot as plt


plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')


plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy')

plt.legend()


plt.show()

# %%
import matplotlib.pyplot as plt


plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# Saving Best Model

# %%
from tensorflow.keras.models import Sequential, model_from_json


model_json = model.to_json()
with open("/kaggle/working/CNN_model.json", "w") as json_file:
    json_file.write(model_json)


model.save_weights("/kaggle/working/CNN_model_weights.weights.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from tensorflow.keras.models import Sequential, model_from_json
json_file = open('/kaggle/input/result/results/CNN_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("/kaggle/input/result/results/best_model1_weights.keras")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %% [markdown]
# Saving and Loading our Stnadrad Scaler and encoder

# %%
import pickle

# Saving scaler
with open('/kaggle/working/scaler2.pickle', 'wb') as f:
    pickle.dump(scaler, f)

# Loading scaler
with open('/kaggle/input/result/results/scaler2.pickle', 'rb') as f:
    scaler2 = pickle.load(f)

# Saving encoder
with open('/kaggle/working/encoder2.pickle', 'wb') as f:
    pickle.dump(encoder, f)

# Loading encoder
with open('/kaggle/input/result/results/encoder2.pickle', 'rb') as f:
    encoder2 = pickle.load(f)

print("Done")
# Out:
# Done

# %% [markdown]
# ## Test script

# %%
from tensorflow.keras.models import Sequential, model_from_json
json_file = open('/kaggle/input/result/results/CNN_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("/kaggle/input/result/results/best_model1_weights.keras")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
import pickle

with open('/kaggle/input/result/results/scaler2.pickle', 'rb') as f:
    scaler2 = pickle.load(f)
    
with open('/kaggle/input/result/results/encoder2.pickle', 'rb') as f:
    encoder2 = pickle.load(f)

    
print("Done")
# Out:
# Done

# %%
import librosa
import numpy as np

def zcr(data,frame_length,hop_length):
    zcr=librosa.feature.zero_crossing_rate(data,frame_length=frame_length,hop_length=hop_length)
    return np.squeeze(zcr)
def rmse(data,frame_length=2048,hop_length=512):
    rmse=librosa.feature.rms(y =data,frame_length=frame_length,hop_length=hop_length)
    return np.squeeze(rmse)
def mfcc(data,sr,frame_length=2048,hop_length=512,flatten:bool=True):
    mfcc=librosa.feature.mfcc(y = data,sr=sr)
    return np.squeeze(mfcc.T)if not flatten else np.ravel(mfcc.T)

def extract_features(data,sr=22050,frame_length=2048,hop_length=512):
    result=np.array([])
    
    result=np.hstack((result,
                      zcr(data,frame_length,hop_length),
                      rmse(data,frame_length,hop_length),
                      mfcc(data,sr,frame_length,hop_length)
                     ))
    return result

# %%
def get_predict_feat(path):
    d, s_rate = librosa.load(path, duration=2.5, offset=0.6)
    res = extract_features(d)
    result = np.array(res)
    # Dynamically adjust the reshape operation based on the actual size of extracted features
    result = np.reshape(result, newshape=(1, -1))
    i_result = scaler2.transform(result)
    final_result = np.expand_dims(i_result, axis=2)
    
    return final_result

# %%
emotions1={1:'Neutral', 2:'Calm', 3:'Happy', 4:'Sad', 5:'Angry', 6:'Fear', 7:'Disgust',8:'Surprise'}
def prediction(path1):
    res=get_predict_feat(path1)
    predictions=loaded_model.predict(res)
    y_pred = encoder2.inverse_transform(predictions)
    print(y_pred[0][0])

# %%
prediction("/kaggle/input/ravdess-emotional-speech-audio/Actor_05/03-01-03-02-01-02-05.wav") # Happy
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# happy

# %% [markdown]
# --

# %%
prediction("/kaggle/input/surrey-audiovisual-expressed-emotion-savee/ALL/DC_a01.wav") # Angry
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# angry

# %%
prediction("/kaggle/input/ravdess-emotional-speech-audio/Actor_03/03-01-02-01-01-01-03.wav") # Calm
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# calm

# %%
prediction("/kaggle/input/surrey-audiovisual-expressed-emotion-savee/ALL/DC_d15.wav") # Disgust
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# disgust

# %%
prediction("/kaggle/input/surrey-audiovisual-expressed-emotion-savee/ALL/DC_f08.wav") # Fear
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# fear

# %%
prediction("/kaggle/input/surrey-audiovisual-expressed-emotion-savee/ALL/DC_n07.wav") # Neutral
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# neutral

# %%
prediction("/kaggle/input/surrey-audiovisual-expressed-emotion-savee/ALL/DC_sa05.wav") # Sad
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# sad

# %%
prediction("/kaggle/input/surrey-audiovisual-expressed-emotion-savee/ALL/DC_su07.wav") # Surprise
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# surprise
